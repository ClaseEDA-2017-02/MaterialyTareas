# %% [markdown]
# # Ejemplo rápido de python
# Hecho en python 2.7

# %% [markdown]
# Como declara y usar una clase

# %%
class stack:
    """Ejemplo de pila"""
    size=0
    datos=[]
    def __init__(self):
        self.datos = []
        self.size=0
    def push(self,n):
        self.datos=[n]+self.datos
        self.size+=1
    def pop(self):
        if self.size >0:
            res=self.datos[0]
            self.datos=self.datos[1:]
        return res
    def toString(self):
        s=""
        for i in self.datos:
            s+=i+" "
        return s

# %%
miPila=stack()

# %%
miPila.push('3')
miPila.push('2')
miPila.push('1')

# %%
print miPila.toString()
# Out:
# 1 2 3

# %%
miPila.pop()
# Out:
# '1'

# %% [markdown]
# Lectura y procesamiento rapido de un archivo

# %%
f=open('datosEj.txt') # poner la ruta y nombre del archivo

# %%
datos=f.read()
# lee todo a un string. veando print datos

# %%
Separados=datos.lower().strip('.,').split() # el argumento de split por default es esoacio. Me regresa una lista

# %% [markdown]
# Contar ocurrencias de cada palabra. Hacer un diccionario

# %%
d={}

# %%
for i in Separados:
    if i in d.keys():
        d[i]=d[i]+1
    else:
        d[i]=0

# %%
sorted(d,key=lambda x: d[x], reverse=True)
# Out:
# ['the',
#  'a',
#  'in',
#  'of',
#  'to',
#  'by',
#  'and',
#  'for',
#  '\xc2\xbb',
#  'new',
#  'on',
#  'is',
#  'with',
#  'that',
#  'york',
#  'was',
#  'it',
#  'has',
#  'as',
#  'at',
#  'his',
#  'times',
#  'health',
#  'trump',
#  'an',
#  'opinion',
#  'state',
#  'after',
#  'how',
#  'news',
#  'but',
#  'your',
#  'from',
#  'who',
#  'he',
#  'u.s.',
#  'said',
#  'comments',
#  'can',
#  'not',
#  '1d',
#  'or',
#  'am',
#  'you',
#  'what',
#  'its',
#  'out',
#  'will',
#  'off',
#  'series',
#  'been',
#  'magazine',
#  'trump\xe2\x80\x99s',
#  'living',
#  'her',
#  'more',
#  'food',
#  'are',
#  '&',
#  'travel',
#  'president',
#  'they',
#  'tech',
#  'had',
#  'people',
#  'navigation',
#  'et',
#  '2',
#  'than',
#  'arts',
#  'theater',
#  'world',
#  '2d',
#  'be',
#  'up',
#  'national',
#  'site',
#  'i',
#  'five',
#  'hate',
#  'estate',
#  'free',
#  'save',
#  'deal',
#  'way',
#  'isis',
#  'inside',
#  'dies',
#  'science',
#  'witch',
# ...

# %%
s="por espacio. o.por,otros"

# %%
s.replace('.',' ').replace(',',' ').split()
# Out:
# ['por', 'espacio', 'o', 'por', 'otros']
